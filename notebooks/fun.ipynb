# %%
from astropy.io import ascii
data=ascii.read("uc.appss.trainset170130 - cnm.appss.trainset170130.csv")
vel=data['Vsys']
fx=data['Flux']

import matplotlib.pyplot as plt
import numpy as np


gaussian_numbers = vel
plt.figure(1)
plt.hist(gaussian_numbers)
plt.title("Velocity Histogram")
plt.xlabel("Velocity [km/s]")
plt.ylabel("Frequency")

#fig1 = plt.gcf()

gaussian_numbers = fx
plt.figure(2)
plt.hist(gaussian_numbers)
plt.title("Flux Histogram")
plt.xlabel("Flux [Jy km/s]")
plt.ylabel("Frequency")

#fig2 = plt.gcf()

plt.show()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from astropy.io import ascii
data1=ascii.read("cnm_training_set.csv")
data2=ascii.read("jsr_training_set.csv")
w50c=data1['W50']
fx1=data1['Flux']
w50j=data2['W50']
fx2=data2['Flux']
dw50=w50c-w50j

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 


plt.figure(1)
plt.hist(w50c,alpha=.5)
plt.hist(w50j,alpha=.5)
plt.title("W50 Histogram")
plt.xlabel("[W50 km/s]")
plt.ylabel("Frequency")




plt.figure(2)
plt.plot(w50c ,w50j,'bs')
plt.title("Flux Histogram")
plt.xlabel("W50 Chelsey [km/s]")
plt.ylabel("W50 Joe [km/s]")
plt.axis([0,450,0,450])


plt.show()

# %%
from astropy.io import ascii
data1=ascii.read("cnm_training_set.csv")
data2=ascii.read("jsr_training_set.csv")
SNc=data1['SN']
fx1=data1['Flux']
SNj=data2['SN']
fx2=data2['Flux']
SN=SNc-SNj

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 


plt.figure(1)
plt.hist(SNc,alpha=.5)
plt.hist(SNj,alpha=.5)
plt.title("SN Histogram")
plt.xlabel("[SN]")
plt.ylabel("Frequency")




plt.figure(2)
plt.plot(SNc ,SNj,'bs')
plt.title("SN Histogram")
plt.xlabel("SN Chelsey [km/s]")
plt.ylabel("SN Joe [km/s]")
plt.axis([0, 20,0,20])




plt.show()

# %%
from astropy.io import ascii
data1=ascii.read("cnm_training_set.csv")
data2=ascii.read("jsr_training_set.csv")
Vsysc=data1['Vsys']
fx1=data1['Flux']
Vsysj=data2['Vsys']
fx2=data2['Flux']
Vsys=Vsysc-Vsysj

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 


plt.figure(1)
plt.hist(Vsysc,alpha=.5)
plt.hist(Vsysj,alpha=.5)
plt.title("Systemic Velocity Histogram")
plt.xlabel("[Systemic Velocity km/s]")
plt.ylabel("Frequency")




plt.figure(2)
plt.plot(Vsysc, Vsysj,'bs')
plt.title("Systemic Velocity Histogram")
plt.xlabel("Systemic Velocity Chelsey [km/s]")
plt.ylabel("Systemic Velocity Joe [km/s]")




plt.show()

# %%
from astropy.io import ascii
data1=ascii.read("cnm_training_set.csv")
data2=ascii.read("jsr_training_set.csv")
Vsysc=data1['Vsys']
fx1=data1['Flux']
Vsysj=data2['Vsys']
fx2=data2['Flux']
Vsys=Vsysc-Vsysj

import matplotlib.pyplot as plt
import numpy as np
import mpld3
# %matplotlib inline 


fg=plt.figure()
plt.plot(Vsysc, Vsysj,'bs')
plt.title("Systemic Velocity Histogram")
plt.xlabel("Systemic Velocity Chelsey [km/s]")
plt.ylabel("Systemic Velocity Joe [km/s]")


plt.show()
mpld3.display(fg)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el5823046374104486799154102"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
# ...

# %%
dif=Vsysc-Vsysj
print(data1['AGCnum'][abs(dif)>1000.],Vsysc[abs(dif)>1000.],Vsysj[abs(dif)>1000.])
# Out:
# (<MaskedColumn name='AGCnum' dtype='int64' length=3>
# 104518
# 115574
# 122930, <MaskedColumn name='Vsys' dtype='float64' length=3>
# 9787.5536
# 5044.0048
#       0.0, <MaskedColumn name='Vsys' dtype='float64' length=3>
# 4890.27
# 4032.32
# 9798.58)

# %%
from astropy.io import ascii
data=ascii.read("test.csv")
vel=data['Vsys']
fx=data['Flux']

import matplotlib.pyplot as plt
import numpy as np


gaussian_numbers = vel
plt.figure(1)
plt.hist(gaussian_numbers)
plt.title("Velocity Histogram")
plt.xlabel("Velocity [km/s]")
plt.ylabel("Frequency")

#fig1 = plt.gcf()

gaussian_numbers = fx
plt.figure(2)
plt.hist(gaussian_numbers)
plt.title("Flux Histogram")
plt.xlabel("Flux [Jy km/s]")
plt.ylabel("Frequency")

#fig2 = plt.gcf()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-23f0a3c1dce1> in <module>()
#       1 from astropy.io import ascii
# ----> 2 data=ascii.read("test.csv")
#       3 vel=data['Vsys']
#       4 fx=data['Flux']
#       5
#
# //anaconda/lib/python2.7/site-packages/astropy/io/ascii/ui.pyc in read(table, guess, **kwargs)
#     311         # through below to the non-guess way so that any problems result in a
#     312         # more useful traceback.
# --> 313         dat = _guess(table, new_kwargs, format, fast_reader_param)
#     314         if dat is None:
#     315             guess = False
#
# //anaconda/lib/python2.7/site-packages/astropy/io/ascii/ui.pyc in _guess(table, read_kwargs, format, fast_reader)
#     449             reader = get_reader(**guess_kwargs)
#     450             reader.guessing = True
# --> 451             dat = reader.read(table)
# ...
